# %%
import numpy as np
import cv2
cv2.__version__
# Out:
# '4.13.0'

# %%
#loasding image
img1=cv2.imread('/content/drive/MyDrive/MLT /cv/ms dhoni image.jpeg')
img1
# Out:
# array([[[48, 63, 72],
#         [46, 61, 70],
#         [43, 58, 67],
#         ...,
#         [60, 68, 58],
#         [60, 68, 58],
#         [60, 68, 58]],
#
#        [[49, 64, 73],
#         [47, 62, 71],
#         [44, 59, 68],
#         ...,
#         [60, 68, 58],
#         [60, 68, 58],
#         [60, 68, 58]],
#
#        [[50, 65, 74],
#         [48, 63, 72],
#         [45, 60, 69],
#         ...,
#         [60, 68, 58],
#         [60, 68, 58],
#         [60, 68, 58]],
#
#        ...,
#
#        [[76, 77, 68],
#         [76, 77, 68],
#         [77, 78, 69],
#         ...,
#         [46, 47, 37],
#         [47, 48, 38],
#         [47, 48, 38]],
#
#        [[75, 76, 67],
#         [76, 77, 68],
#         [77, 78, 69],
#         ...,
#         [46, 47, 37],
#         [47, 48, 38],
#         [47, 48, 38]],
#
#        [[75, 76, 67],
#         [76, 77, 68],
#         [77, 78, 69],
#         ...,
#         [47, 48, 38],
#         [47, 48, 38],
#         [47, 48, 38]]], dtype=uint8)

# %%
imagem = cv2.imread('/content/drive/MyDrive/MLT /cv/ms dhoni image.jpeg',)
gray_image = cv2.cvtColor(imagem, cv2.COLOR_BGR2GRAY)
# Out:
# array([[64, 62, 59, ..., 64, 64, 64],
#        [65, 63, 60, ..., 64, 64, 64],
#        [66, 64, 61, ..., 64, 64, 64],
#        ...,
#        [74, 74, 75, ..., 44, 45, 45],
#        [73, 74, 75, ..., 44, 45, 45],
#        [73, 74, 75, ..., 45, 45, 45]], dtype=uint8)
