# %% [markdown]
# <a href="https://colab.research.google.com/github/Gokul1-6/Deep_Learning/blob/main/IMAGE_PROCESSING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2
cv2.__version__

# %%
#loasding image
img1=cv2.imread('/content/drive/MyDrive/MLT /cv/ms dhoni image.jpeg')
img1

# %%
#image display
from google.colab.patches import cv2_imshow
cv2_imshow(img)

# %%
#loasding image
img=cv2.imread('/content/drive/MyDrive/MLT /cv/ms dhoni image.jpeg',0)
cv2_imshow(img)

# %%
cv2.imwrite('msd.jpg',img)

# %%
print(img1.shape)
print(img.size)
print(img.dtype)
print(img.ndim)

# %%
#image_slicing
img1=img1[20:172,40:234]
img1

# %%
#image_rotating
img3=cv2.rotate(img1,cv2.ROTATE_90_CLOCKWISE)
cv2_imshow(img3)

# %%
#image fliping
img2=cv2.flip(img,0)
from google.colab.patches import cv2_imshow
cv2_imshow(img2)

# %%
img2=cv2.flip(img,1)
from google.colab.patches import cv2_imshow
cv2_imshow(img2)

# %%
#image resize
img3=cv2.resize(img,(100,100))
cv2_imshow(img3)

# %%
img3=cv2.resize(img,(50,30))
cv2_imshow(img3)

# %%
#image bluring
img4=cv2.blur(img1,(20,10))
cv2_imshow(img4)
